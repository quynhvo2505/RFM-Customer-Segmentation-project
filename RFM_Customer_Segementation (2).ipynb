# %% [markdown]
# #**Objective**
#
# To develop an interactive dashboard that integrates customer, geographic, and purchase data to identify who high-value customers are, where they are located, and what they buy—enabling actionable insights and continuous, data-driven decision-making.

# %% [markdown]
# # **1. Import Library**

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from datetime import datetime

# %% [markdown]
# # **2. Data Loading and Preprocessing**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_customers = pd.read_csv('/content/drive/MyDrive/Xom Analytics class/Buoi 6 Cohort analysis/Buoi 6 HW/Customer (1).csv')
df_ecomsales = pd.read_csv('/content/drive/MyDrive/Xom Analytics class/Buoi 6 Cohort analysis/Buoi 6 HW/EcomSales (2).csv')
df_products = pd.read_csv('/content/drive/MyDrive/Xom Analytics class/Buoi 6 Cohort analysis/Buoi 6 HW/Product (3).csv')
df_region = pd.read_csv('/content/drive/MyDrive/Xom Analytics class/Buoi 6 Cohort analysis/Buoi 6 HW/Region (1).csv')

# %%
df_ecomsales
# Out:
#        RowID                  OrderID   OrderDate  CustomerID        Segment  \
# 0      25221   IN-2012-TH211151-41003    4/4/2020   TH-211151      Corporate
# 1      29464   ID-2013-BD116051-41518    9/1/2021   BD-116051       Consumer
# 2      27311   IN-2015-TS212051-42173   6/18/2023   TS-212051      Corporate
# 3      28882   IN-2014-SU206651-41899   9/17/2022   SU-206651  Self-Employed
# 4      27992   IN-2015-GM144551-42217    8/1/2023   GM-144551  Self-Employed
# ...      ...                      ...         ...         ...            ...
# 51285  42718  ZA-2015-GR4560147-42216   7/31/2023  GR-4560147      Corporate
# 51286  43446  ZA-2015-BT1395147-42336  11/28/2023  BT-1395147      Corporate
# 51287  42929  ZA-2013-DN3690147-41429    6/4/2021  DN-3690147       Consumer
# 51288  42930  ZA-2013-DN3690147-41429    6/4/2021  DN-3690147       Consumer
# 51289  49480  ZA-2015-BT1305147-42338  11/30/2023  BT-1305147  Self-Employed
#
# ...

# %%
df_ecomsales['Revenue'] = df_ecomsales['Sales'] - (df_ecomsales['Discount'] * df_ecomsales['Sales'])
display(df_ecomsales.head(20))
# Out:
#     RowID                 OrderID   OrderDate CustomerID        Segment  \
# 0   25221  IN-2012-TH211151-41003    4/4/2020  TH-211151      Corporate
# 1   29464  ID-2013-BD116051-41518    9/1/2021  BD-116051       Consumer
# 2   27311  IN-2015-TS212051-42173   6/18/2023  TS-212051      Corporate
# 3   28882  IN-2014-SU206651-41899   9/17/2022  SU-206651  Self-Employed
# 4   27992  IN-2015-GM144551-42217    8/1/2023  GM-144551  Self-Employed
# 5   24598  IN-2015-CA120551-42085   3/22/2023  CA-120551  Self-Employed
# 6   29465  ID-2013-BD116051-41518    9/1/2021  BD-116051       Consumer
# 7   29095  IN-2013-BG110351-41545   9/28/2021  BG-110351       Consumer
# 8   25231  ID-2013-SS201401-41624  12/16/2021  SS-201401      Corporate
# 9   25220  IN-2012-TH211151-41003    4/4/2020  TH-211151      Corporate
# 10  29097  IN-2013-BG110351-41545   9/28/2021  BG-110351       Consumer
# 11  27310  IN-2015-TS212051-42173   6/18/2023  TS-212051      Corporate
# ...

# %% [markdown]
# # **3. Table Merging**

# %%
df= df_ecomsales.merge(df_customers, on='CustomerID', how= 'inner')
df.head(10)
# Out:
#    RowID                 OrderID   OrderDate CustomerID        Segment  \
# 0  25221  IN-2012-TH211151-41003    4/4/2020  TH-211151      Corporate
# 1  29464  ID-2013-BD116051-41518    9/1/2021  BD-116051       Consumer
# 2  27311  IN-2015-TS212051-42173   6/18/2023  TS-212051      Corporate
# 3  28882  IN-2014-SU206651-41899   9/17/2022  SU-206651  Self-Employed
# 4  27992  IN-2015-GM144551-42217    8/1/2023  GM-144551  Self-Employed
# 5  24598  IN-2015-CA120551-42085   3/22/2023  CA-120551  Self-Employed
# 6  29465  ID-2013-BD116051-41518    9/1/2021  BD-116051       Consumer
# 7  29095  IN-2013-BG110351-41545   9/28/2021  BG-110351       Consumer
# 8  25231  ID-2013-SS201401-41624  12/16/2021  SS-201401      Corporate
# 9  25220  IN-2012-TH211151-41003    4/4/2020  TH-211151      Corporate
#
#   RegionCode ProductCode  Quantity  Sales  Discount  ...  FirstName  LastName  \
# 0    RRR0001     P000001        13    416       0.0  ...        Jon     Huang
# ...

# %% [markdown]
# # **4. RFM Analysis**

# %%
df_rfm_groupby = df_ecomsales.groupby(by = 'CustomerID',as_index=False).agg(max_date = ('OrderDate','max')
                                                                     ,frequency = ('OrderID','nunique')
                                                                     ,monetary = ('Revenue','sum'))

# %%
df_rfm_groupby['recency'] = (datetime.now() - pd.to_datetime(df_rfm_groupby['max_date'])).dt.days

# %%
df_rfm_groupby
# Out:
#          CustomerID    max_date  frequency  monetary  recency
# 0       AA-10315102    7/3/2020          2   506.800     2113
# 1       AA-10315120   5/16/2021          1    63.000     1796
# 2       AA-10315139   9/19/2022          4   596.600     1305
# 3      AA-103151402   6/30/2023          2   195.800     1021
# 4      AA-103151404   3/30/2020          2   213.600     2208
# ...             ...         ...        ...       ...      ...
# 17410    ZD-2192548   8/17/2021          3   164.200     1703
# 17411    ZD-2192564   2/21/2020          1   152.000     2246
# 17412     ZD-219257   9/19/2020          1   111.600     2035
# 17413    ZD-2192582   6/18/2023          2   126.354     1033
# 17414    ZD-2192596  12/12/2021          1   112.000     1586
#
# [17415 rows x 5 columns]

# %%
df_rfm_groupby['R_score'] = pd.qcut(df_rfm_groupby['recency'], q = 5, duplicates='drop')
df_rfm_groupby['F_score'] = pd.qcut(df_rfm_groupby['frequency'], q = 5, duplicates='drop')
df_rfm_groupby['M_score'] = pd.qcut(df_rfm_groupby['monetary'], q = 5, duplicates='drop')

df_rfm_groupby
# Out:
#          CustomerID    max_date  frequency  monetary  recency  \
# 0       AA-10315102    7/3/2020          2   506.800     2113
# 1       AA-10315120   5/16/2021          1    63.000     1796
# 2       AA-10315139   9/19/2022          4   596.600     1305
# 3      AA-103151402   6/30/2023          2   195.800     1021
# 4      AA-103151404   3/30/2020          2   213.600     2208
# ...             ...         ...        ...       ...      ...
# 17410    ZD-2192548   8/17/2021          3   164.200     1703
# 17411    ZD-2192564   2/21/2020          1   152.000     2246
# 17412     ZD-219257   9/19/2020          1   111.600     2035
# 17413    ZD-2192582   6/18/2023          2   126.354     1033
# 17414    ZD-2192596  12/12/2021          1   112.000     1586
#
#                 R_score           M_score       F_score
# 0      (1843.0, 2297.0]  (459.04, 6840.0]  (0.999, 2.0]
# 1      (1523.0, 1843.0]      (38.0, 96.0]  (0.999, 2.0]
# ...

# %%
df_rfm_groupby['F_score'].unique()
# Out:
# [(0.999, 2.0], (2.0, 9.0]]
# Categories (2, interval[float64, right]): [(0.999, 2.0] < (2.0, 9.0]]

# %%
df_rfm_groupby['R_score'] = pd.qcut(df_rfm_groupby['recency'], q=5, labels=[5, 4, 3, 2, 1], duplicates='drop')
df_rfm_groupby['M_score'] = pd.qcut(df_rfm_groupby['monetary'], q=5, labels=[1, 2, 3, 4, 5], duplicates='drop')
df_rfm_groupby
# Out:
#          CustomerID    max_date  frequency  monetary  recency R_score M_score  \
# 0       AA-10315102    7/3/2020          2   506.800     2113       1       5
# 1       AA-10315120   5/16/2021          1    63.000     1796       2       2
# 2       AA-10315139   9/19/2022          4   596.600     1305       3       5
# 3      AA-103151402   6/30/2023          2   195.800     1021       4       3
# 4      AA-103151404   3/30/2020          2   213.600     2208       1       4
# ...             ...         ...        ...       ...      ...     ...     ...
# 17410    ZD-2192548   8/17/2021          3   164.200     1703       2       3
# 17411    ZD-2192564   2/21/2020          1   152.000     2246       1       3
# 17412     ZD-219257   9/19/2020          1   111.600     2035       1       3
# 17413    ZD-2192582   6/18/2023          2   126.354     1033       4       3
# 17414    ZD-2192596  12/12/2021          1   112.000     1586       2       3
#
# ...

# %%
df_rfm_groupby = df_rfm_groupby.drop(columns=['F_Score', 'F_score_x', 'F_score_y'], errors='ignore')

# %%
df_freq = df_rfm_groupby['frequency'].unique()
df_freq = pd.DataFrame(df_freq, columns=['frequency'])

df_freq['F_score'] = pd.qcut(df_freq['frequency'], q=5, labels=[1, 2, 3, 4, 5])
df_freq
# Out:
#    frequency F_score
# 0          2       1
# 1          1       1
# 2          4       2
# 3          3       2
# 4          5       3
# 5          6       4
# 6          7       4
# 7          9       5
# 8          8       5

# %%
df_rfm_groupby = df_rfm_groupby.merge(
    df_freq[['frequency', 'F_score']],
    on='frequency',
    how='left'
)
df_rfm_groupby.head()
# Out:
#      CustomerID   max_date  frequency  monetary  recency R_score M_score  \
# 0   AA-10315102   7/3/2020          2     506.8     2113       1       5
# 1   AA-10315120  5/16/2021          1      63.0     1796       2       2
# 2   AA-10315139  9/19/2022          4     596.6     1305       3       5
# 3  AA-103151402  6/30/2023          2     195.8     1021       4       3
# 4  AA-103151404  3/30/2020          2     213.6     2208       1       4
#
#   F_score
# 0       1
# 1       1
# 2       2
# 3       1
# 4       1

# %%
df_rfm_groupby.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17415 entries, 0 to 17414
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  17415 non-null  object
#  1   max_date    17415 non-null  object
#  2   frequency   17415 non-null  int64
#  3   monetary    17415 non-null  float64
#  4   recency     17415 non-null  int64
#  5   R_score     17415 non-null  category
#  6   M_score     17415 non-null  category
#  7   F_score     17415 non-null  category
# dtypes: category(3), float64(1), int64(2), object(2)
# memory usage: 732.0+ KB

# %%
df_rfm_groupby['R_score'] = df_rfm_groupby['R_score'].astype(int)
df_rfm_groupby['F_score'] = df_rfm_groupby['F_score'].astype(int)
df_rfm_groupby['M_score'] = df_rfm_groupby['M_score'].astype(int)
df_rfm_groupby.head()
# Out:
#      CustomerID   max_date  frequency  monetary  recency  R_score  M_score  \
# 0   AA-10315102   7/3/2020          2     506.8     2113        1        5
# 1   AA-10315120  5/16/2021          1      63.0     1796        2        2
# 2   AA-10315139  9/19/2022          4     596.6     1305        3        5
# 3  AA-103151402  6/30/2023          2     195.8     1021        4        3
# 4  AA-103151404  3/30/2020          2     213.6     2208        1        4
#
#    F_score
# 0        1
# 1        1
# 2        2
# 3        1
# 4        1

# %%
df_rfm_groupby['F_score'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df_rfm_groupby['RFM_score'] = df_rfm_groupby['R_score'] * 100 + df_rfm_groupby['F_score'] * 10 + df_rfm_groupby['M_score']
df_rfm_groupby
# Out:
#          CustomerID    max_date  frequency  monetary  recency  R_score  \
# 0       AA-10315102    7/3/2020          2   506.800     2113        1
# 1       AA-10315120   5/16/2021          1    63.000     1796        2
# 2       AA-10315139   9/19/2022          4   596.600     1305        3
# 3      AA-103151402   6/30/2023          2   195.800     1021        4
# 4      AA-103151404   3/30/2020          2   213.600     2208        1
# ...             ...         ...        ...       ...      ...      ...
# 17410    ZD-2192548   8/17/2021          3   164.200     1703        2
# 17411    ZD-2192564   2/21/2020          1   152.000     2246        1
# 17412     ZD-219257   9/19/2020          1   111.600     2035        1
# 17413    ZD-2192582   6/18/2023          2   126.354     1033        4
# 17414    ZD-2192596  12/12/2021          1   112.000     1586        2
#
#        M_score  F_score  RFM_score
# 0            5        1        115
# 1            2        1        212
# ...

# %% [markdown]
# #  **5. Customer Segmentation**

# %%
df_rfm_groupby['RFM_Segment'] = 'Other'

# Champions
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([555, 554, 544, 545, 454, 455, 445]), 'RFM_Segment'] = 'Champions'

# Loyal
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([543, 444, 435, 355, 354, 345, 344, 335]), 'RFM_Segment'] = 'Loyal'

# Potential Loyalist
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([553, 551, 552, 541, 542, 533, 532, 531, 452, 451
                                                 , 442, 441, 431, 453, 433, 432, 423, 353, 352
                                                 , 351, 342, 341, 333, 323]), 'RFM_Segment'] = 'Potential Loyalist'

# Promising
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([525, 524, 523, 522, 521, 515, 514, 513
                                                 , 425, 424, 413, 414, 415, 315, 314, 313]), 'RFM_Segment'] = 'Promising'

# New Customers
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([512, 511, 422, 421, 412, 411, 311]), 'RFM_Segment'] = 'New Customers'

# Need Attention
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([535, 534, 443, 434, 343, 334, 325, 324]), 'RFM_Segment'] = 'Need Attention'

# About To Sleep
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([331, 321, 312, 221, 213, 231, 241, 251]), 'RFM_Segment'] = 'About To Sleep'

# At Risk
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([255, 254, 245, 244, 253, 252, 243, 242, 235
                                                 , 234, 225, 224, 153, 152, 145, 143, 142
                                                 , 135, 134, 133, 125, 124]), 'RFM_Segment'] = 'At Risk'

# Cannot Lose Them
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([155, 154, 144, 214, 215, 115, 114, 113]), 'RFM_Segment'] = 'Cannot Lose Them'

# Hibernating customers
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([332, 322, 233, 232, 223, 222, 132, 123, 122, 212, 211]), 'RFM_Segment'] = 'Hibernating customers'

# Lost customers
df_rfm_groupby.loc[df_rfm_groupby['RFM_score'].isin([111, 112, 121, 131, 141, 151]), 'RFM_Segment'] = 'Lost customers'

df_rfm_groupby
# Out:
#          CustomerID    max_date  frequency  monetary  recency  R_score  \
# 0       AA-10315102    7/3/2020          2   506.800     2113        1
# 1       AA-10315120   5/16/2021          1    63.000     1796        2
# 2       AA-10315139   9/19/2022          4   596.600     1305        3
# 3      AA-103151402   6/30/2023          2   195.800     1021        4
# 4      AA-103151404   3/30/2020          2   213.600     2208        1
# ...             ...         ...        ...       ...      ...      ...
# 17410    ZD-2192548   8/17/2021          3   164.200     1703        2
# 17411    ZD-2192564   2/21/2020          1   152.000     2246        1
# 17412     ZD-219257   9/19/2020          1   111.600     2035        1
# 17413    ZD-2192582   6/18/2023          2   126.354     1033        4
# 17414    ZD-2192596  12/12/2021          1   112.000     1586        2
#
#        M_score  F_score  RFM_score            RFM_Segment
# ...

# %%
treemap_input = df_rfm_groupby.groupby(by = 'RFM_Segment',as_index=False).agg(count_cus = ('CustomerID','nunique')
                                                                            ,total_rev = ('monetary','sum'))
treemap_input
# Out:
#               RFM_Segment  count_cus    total_rev
# 0          About To Sleep       1285   136707.560
# 1                 At Risk        651   591595.136
# 2        Cannot Lose Them       2747  1379843.820
# 3               Champions         14    19791.460
# 4   Hibernating customers       1497    75106.312
# 5          Lost customers       1413    60026.484
# 6                   Loyal         61    98460.346
# 7          Need Attention        432   386234.822
# 8           New Customers       3538   134325.044
# 9      Potential Loyalist        103    15487.976
# 10              Promising       5674  2667504.140

# %% [markdown]
# # **6. Visualization**

# %%
# Create a Treemap for customer count
fig = px.treemap(treemap_input, path=['RFM_Segment'], values='count_cus', title='RFM Segments - Customer Count Treemap')

# Show the plot
fig.show()

# Create a Treemap for total revenue
fig_rev = px.treemap(treemap_input, path=['RFM_Segment'], values='total_rev', title='RFM Segments - Total Revenue Treemap')

# Show the revenue plot
fig_rev.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.to_csv('Customer_data.csv', index=False)
df_rfm_groupby.to_csv('rfm_segments.csv', index=False)

# %%
import os
os.listdir('/content')
# Out:
# ['.config',
#  'rfm_segments.csv',
#  'drive',
#  'Customer_data.csv',
#  'full_dashboard_data.csv',
#  'sample_data']

# %%
from google.colab import files
files.download('Customer_data.csv')
files.download('rfm_segments.csv')

# %%
df_full['Revenue'].dtype        # phải là float64
df_full['Revenue'].head()
# Out:
# 0    416.0
# 1     20.0
# 2     20.0
# 3    556.0
# 4      6.0
# Name: Revenue, dtype: float64
